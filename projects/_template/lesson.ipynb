# %% [markdown]
# # Day NN — <Concept>
#
# **Time budget: 60 minutes.** Segment headings carry their own timebox. If you overrun badly, stop
# and split the topic across two days rather than rushing the hands-on parts.
#
# ## How to use this notebook
#
# 1. Read the markdown, then run the code cell under it before reading on. The cells build on each
#    other, so run them in order.
# 2. When a cell says *predict first*, write down your guess before running it. Being wrong is the
#    part that sticks.
# 3. Finish with the exercises at the bottom. Solutions are there, but try first.
#
# ## Agenda
#
# | # | Segment | Time |
# | - | ------- | ---- |
# | 0 | <framing> | 3 min |
# | 1 | <naive approach and its failure> | 8 min |
# | 2 | <real mechanism, hands-on> | 12 min |
# | 3 | <build from scratch> | 10 min |
# | 4 | <connect to bigger picture> | 5 min |
# | 5 | <the deep part> | 15 min |
# | 6 | <bridge to next> | 7 min |
# | 7 | Exercises and quiz | — |

# %%
import numpy as np

np.random.seed(0)
np.set_printoptions(precision=3, suppress=True)
print("ready")

# %% [markdown]
# ---
# ## 0. <Framing> (3 min)
#
# <The question this hour answers, in two or three sentences. State it as a problem, not a topic.>

# %% [markdown]
# ---
# ## 1. <The naive approach> (8 min)
#
# <Describe the obvious first idea. Then break it in a cell so the fix is motivated.>

# %%
# the naive approach, working

# %%
# the naive approach, failing -- this is the point of the segment

# %% [markdown]
# ---
# ## 2. <The real mechanism> (12 min)
#
# <Introduce the actual technique. Hands-on, with library support if appropriate.>

# %%
# hands-on

# %% [markdown]
# ---
# ## 3. <Build it from scratch> (10 min)
#
# <Reimplement the core of segment 2 in ~30 lines so it stops being a black box.>

# %%
# from-scratch implementation

# %% [markdown]
# ---
# ## 4. <Connect to the bigger picture> (5 min)
#
# <Where this sits in a real system. Parameter counts, shapes, costs -- concrete numbers.>

# %%
# the connecting demonstration

# %% [markdown]
# ---
# ## 5. <The deep part> (15 min)
#
# <The heart of the lesson: full implementation, trained or executed, then evaluated.>

# %%
# implementation

# %%
# evaluation

# %% [markdown]
# ---
# ## 6. <Bridge to what comes next> (7 min)
#
# <Honest limits of what you just built, and which idea fixes each limit.>

# %% [markdown]
# ---
# ## 7. Exercises
#
# Try each before opening the solution.
#
# **Exercise 1.** <task>
#
# **Exercise 2.** <task>
#
# **Exercise 3.** <task>
#
# **Exercise 4.** <task>
#
# **Exercise 5.** <task>

# %%
# Your scratch space for the exercises.

# %% [markdown]
# <details>
# <summary><b>Solutions</b> (click to expand)</summary>
#
# ```python
# # Exercise 1
# ```
#
# </details>

# %% [markdown]
# ---
# ## Self-check quiz
#
# If you cannot answer these without scrolling up, reread the segment named in the answer.
#
# 1. <question>
# 2. <question>
# 3. <question>
# 4. <question>
# 5. <question>
#
# <details>
# <summary><b>Answers</b></summary>
#
# 1. <answer> (segment N)
#
# </details>

# %% [markdown]
# ---
# ## Where to go next
#
# <One concrete next concept and why it follows from this one.>
